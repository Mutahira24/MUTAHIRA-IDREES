# %%
import matplotlib.pyplot as plt

import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)

# %%
X, y = datasets.load_diabetes(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (442, 10)
# [ 0.03807591  0.05068012  0.06169621  0.02187239 -0.0442235  -0.03482076
#  -0.04340085 -0.00259226  0.01990749 -0.01764613]

# %%
# Extract the column at index 2
X = X[:,2]
print(X.shape)

# Reshape to a 2D array
X = X.reshape(-1, 1)
print(X.shape)
# Out:
# (442,)
# (442, 1)

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
# creat a linear reggrission model and train it with our data
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# prediction using test data
y_pred = model.predict(X_test)

# %%
# creat a scatter plot
plt.scatter(X_test, y_test,  color='blue')
plt.plot(X_test, y_pred, color='black', linewidth=3)
plt.xlabel('Scaled BMIs')
plt.ylabel('Disease Progression')
plt.title('A Graph Plot Showing Diabetes Progression Against BMI')
plt.show()

# %%
# Load diabetes dataset
diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target

# Choose a different variable, e.g., column 5 (S5 - blood serum measurement)
X_feature = X[:, 5]

plt.scatter(X_feature, y, color='blue')
plt.plot(X_test, y_pred, color='black', linewidth=3)
plt.xlabel('Feature column 5 (S5 - blood serum measurement)')
plt.ylabel('Disease progression')
plt.title('Feature vs Diabetes Progression')
plt.show()
