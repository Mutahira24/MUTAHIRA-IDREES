# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score
# Load the Linnerud dataset
linnerud_X,linnerud_y = datasets.load_linnerud(return_X_y=True)

# %%
X, y = datasets.load_linnerud(return_X_y=True)
print(X.shape)
print(X[0])
# Out:
# (20, 3)
# [  5. 162.  60.]

# %%
# Extract the column at index 2
X = X[:,2]
print(X.shape)

# Reshape to a 2D array
X = X.reshape(-1, 1)
print(X.shape)
# Out:
# (20,)
# (20, 1)

# %%
from sklearn import model_selection

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33)

# %%
# creat a linear reggrission model and train it with our data
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# prediction using test data
y_pred = model.predict(X_test)

# %%
from sklearn.datasets import load_linnerud
import matplotlib.pyplot as plt

linnerud = load_linnerud()
X = linnerud.data
y = linnerud.target

plt.scatter(X[:, 0], y[:, 0], color='blue')  # Chin-ups vs Weight

plt.xlabel('Chin-ups')
plt.ylabel('Weight (kg)')
plt.title('Weight vs Chin-ups')
plt.show()
